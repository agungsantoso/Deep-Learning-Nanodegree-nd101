# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

t = 1e-5
word_counts = Counter(int_words)
total = len(int_words)
f = {w_i : n / total for w_i, n in word_counts.items()}
P = {w_i : 1 - np.sqrt(t / f[w_i]) for w_i in word_counts}
train_words = [w_i for w_i in int_words if P[w_i] < random.random() ] # The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = 1 + np.random.randint(window_size)
    start_idx = idx - R if (idx - R) > 0 else 0
    end_idx = idx + R + 1
    
    return list(set(words[start_idx:idx] + words[idx+1:end_idx]))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name="inputs")
    labels = tf.placeholder(tf.int32, [None, None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform(shape=(n_vocab, n_embedding),
                                              minval=-1,
                                              maxval=1)) 
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal(shape=(n_vocab, n_embedding),
                                                stddev=0.1))
    # create softmax biases here
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights=softmax_w,
                                      biases=softmax_b, 
                                      labels=labels, 
                                      inputs=embed, 
                                      num_sampled=n_sampled, 
                                      num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6440 0.0785 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6173 0.0768 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4942 0.0775 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5843 0.0774 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4750 0.0772 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4990 0.0770 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5479 0.0769 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5736 0.0769 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4719 0.0776 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4595 0.0770 sec/batch
# Nearest to which: meister, leuven, raise, craig, motivic, annuities, bacall, melisende,
# Nearest to history: treading, tokai, officiate, andes, nahin, endings, milos, rumelia,
# Nearest to seven: nods, strident, resonates, bez, kou, clandestinely, orator, ah,
# Nearest to have: genji, colonisation, xis, pillaged, newsforge, compulsive, groklaw, overpower,
# Nearest to so: torrential, sonata, burnings, head, salient, angles, occasionally, binitarianism,
# Nearest to four: jumper, region, mansfeld, emmet, cumulus, pearson, dolby, eras,
# Nearest to their: lars, turnbull, carib, ketuvim, destitute, bacilli, beaches, clays,
# Nearest to used: might, alumnus, absinthium, clashing, rabia, corfu, solver, castrati,
# Nearest to taking: heated, prodigal, interface, wiecino, sines, freitas, essais, portage,
# Nearest to articles: pagan, ghazi, indexing, karoo, misr, patronymics, durante, conferred,
# Nearest to lived: bayern, ul, beatified, lia, hysteria, implant, judgements, portals,
# Nearest to something: willey, ground, golomb, right, vauxhall, cowdery, stew, goguryeo,
# Nearest to report: hawat, anxious, oran, rearrangements, soldier, godf, subcultures, canals,
# Nearest to running: kakatiya, redeeming, litigated, neopagans, vendetta, hijaz, lively, praia,
# Nearest to professional: longbows, daimon, adventurers, filmfour, pep, grimm, whole, wordperfect,
# Nearest to grand: micronova, thessaloniki, tuareg, tailoring, diabolical, sanitarium, poke, prevention,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5093 0.0788 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4007 0.0767 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3718 0.0768 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2514 0.0767 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1892 0.0763 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1580 0.0766 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1004 0.0767 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0739 0.0774 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0062 0.0773 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9850 0.0770 sec/batch
# Nearest to which: raise, craig, meister, individual, large, thus, exception, atoms,
# Nearest to history: endings, officiate, appoint, boyars, treading, bring, rumelia, andes,
# Nearest to seven: strident, nods, number, extinct, tips, orator, kou, organizations,
# Nearest to have: colonisation, genji, pillaged, density, necessary, remixed, v, useless,
# Nearest to so: head, occasionally, torrential, applies, burnings, salient, angles, wise,
# Nearest to four: region, jumper, pearson, mansfeld, emmet, weather, cumulus, diodes,
# Nearest to their: the, lars, estate, destinations, suitable, dispute, define, dating,
# Nearest to used: might, alumnus, countries, physical, france, connected, ay, underlying,
# Nearest to taking: heated, prodigal, interface, widely, sign, interstates, coot, disorders,
# Nearest to articles: pagan, jackpots, karoo, conferred, ghazi, patronymics, venetian, strongly,
# Nearest to lived: profits, judgements, hysteria, grip, portals, implant, personalities, qualify,
# Nearest to something: ground, right, golomb, willey, magnetic, aired, hands, up,
# Nearest to report: anxious, soldier, oran, subcultures, rearrangements, hawat, started, canals,
# Nearest to running: litigated, kakatiya, huang, picked, mortar, clothed, lively, neopagans,
# Nearest to professional: whole, longbows, grimm, daimon, filmfour, adventurers, discrete, pep,
# Nearest to grand: micronova, thessaloniki, tuareg, tailoring, diabolical, still, miracles, return,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9603 0.0782 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9056 0.0773 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8846 0.0772 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8465 0.0770 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8256 0.0766 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8115 0.0764 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8054 0.0773 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8246 0.0764 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7883 0.0766 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7925 0.0768 sec/batch
# Nearest to which: raise, individual, meister, atoms, thus, subtracting, leuven, craig,
# Nearest to history: wilson, appoint, endings, indebted, bring, audubon, officiate, winchester,
# Nearest to seven: six, strident, extinct, orator, ct, tips, invincible, ah,
# Nearest to have: genji, colonisation, density, pressburg, sensual, pillaged, useless, compulsive,
# Nearest to so: occasionally, head, sonata, torrential, angles, applies, wise, binitarianism,
# Nearest to four: pearson, jumper, region, migrant, mansfeld, crests, one, weather,
# Nearest to their: lars, beaches, destinations, motions, helpful, the, ketuvim, dispute,
# Nearest to used: might, alumnus, brooklyn, clashing, euphemistic, countries, solver, termination,
# Nearest to taking: heated, prodigal, essais, interface, sign, interstates, portage, inspections,
# Nearest to articles: pagan, conferred, jackpots, strongly, how, venetian, indexing, noyes,
# Nearest to lived: beatified, lion, profits, portals, judgements, implant, lia, hysteria,
# Nearest to something: ground, right, willey, golomb, magnetic, stew, aired, vauxhall,
# Nearest to report: anxious, soldier, subcultures, oran, rearrangements, canals, stratigraphic, hawat,
# Nearest to running: picked, litigated, neopagans, stepped, lively, kakatiya, clothed, huang,
# Nearest to professional: whole, grimm, adventurers, longbows, daimon, pep, discrete, filmfour,
# Nearest to grand: micronova, thessaloniki, still, tuareg, return, miracles, tailoring, diabolical,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7891 0.0786 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7213 0.0761 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7308 0.0773 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6912 0.0765 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7396 0.0779 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7013 0.0775 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7156 0.0773 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7209 0.0770 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6910 0.0770 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6779 0.0772 sec/batch
# Nearest to which: residues, raise, meister, individual, atoms, melody, thus, autoimmune,
# Nearest to history: wilson, appoint, audubon, treading, indebted, andes, rumelia, officiate,
# Nearest to seven: six, eight, writer, orator, five, four, strident, extinct,
# Nearest to have: genji, colonisation, compulsive, pressburg, sensual, formulated, bazaar, segregation,
# Nearest to so: occasionally, sonata, head, torrential, binitarianism, salient, wise, angles,
# Nearest to four: one, pearson, nine, jumper, five, migrant, zero, runways,
# Nearest to their: beaches, the, motions, week, dispute, turnbull, ketuvim, convincing,
# Nearest to used: might, euphemistic, solver, clashing, brooklyn, shipped, physical, termination,
# Nearest to taking: heated, prodigal, portage, courtroom, fateful, inspections, essais, interrelated,
# Nearest to articles: pagan, jackpots, conferred, indexing, karoo, how, strongly, versed,
# Nearest to lived: beatified, portals, lia, personalities, bayern, lion, implant, dandies,
# Nearest to something: right, ground, willey, golomb, stew, magnetic, goguryeo, cowdery,
# Nearest to report: anxious, subcultures, soldier, oran, rearrangements, hawat, canals, stratigraphic,
# Nearest to running: litigated, kakatiya, stepped, hijaz, redeeming, picked, insignificant, neopagans,
# Nearest to professional: grimm, adventurers, pep, longbows, whole, daimon, underlie, forty,
# Nearest to grand: micronova, thessaloniki, tuareg, still, return, poke, miracles, margrave,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6615 0.0780 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6665 0.0774 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6207 0.0778 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6263 0.0768 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6220 0.0774 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6330 0.0757 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6196 0.0554 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5450 0.0767 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5061 0.0769 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5005 0.0768 sec/batch
# Nearest to which: residues, raise, meister, deciphering, thus, atoms, zayd, opcodes,
# Nearest to history: wilson, appoint, audubon, hers, treading, indebted, rumelia, officiate,
# Nearest to seven: six, eight, writer, five, politician, painter, orator, organist,
# Nearest to have: genji, colonisation, formulated, pressburg, sensual, compulsive, segregation, bazaar,
# Nearest to so: occasionally, sonata, head, binitarianism, torrential, angles, applies, wise,
# Nearest to four: one, nine, pearson, five, jumper, von, zero, emmet,
# Nearest to their: helpful, motions, the, dispute, ketuvim, leadership, week, turnbull,
# Nearest to used: might, euphemistic, solver, underlying, paradigm, shipped, bundles, clashing,
# Nearest to taking: heated, portage, prodigal, courtroom, inspections, interstates, fateful, sign,
# Nearest to articles: pagan, conferred, jackpots, versed, karoo, strongly, patronymics, indexing,
# Nearest to lived: beatified, bayern, portals, lia, hogeschool, deutschland, faure, ul,
# Nearest to something: right, stew, golomb, willey, magnetic, ground, spectrometer, cowdery,
# Nearest to report: anxious, oran, subcultures, rearrangements, canals, soldier, hawat, overlooked,
# Nearest to running: redeeming, litigated, kakatiya, picked, neopagans, insignificant, networked, stepped,
# Nearest to professional: grimm, adventurers, longbows, pep, remarkable, forty, paar, underlie,
# Nearest to grand: micronova, thessaloniki, tuareg, margrave, poke, return, hospitalised, still,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4835 0.0783 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4938 0.0771 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4676 0.0774 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5281 0.0771 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5002 0.0773 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4738 0.0768 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4329 0.0770 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4055 0.0776 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4350 0.0769 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4268 0.0774 sec/batch
# Nearest to which: residues, meister, raise, thus, atoms, individual, interactively, zayd,
# Nearest to history: wilson, treading, hers, andes, indebted, rumelia, audubon, winchester,
# Nearest to seven: six, eight, five, writer, strident, four, politician, deniz,
# Nearest to have: genji, formulated, colonisation, segregation, compulsive, antithetical, pressburg, sensual,
# Nearest to so: occasionally, sonata, head, dopamine, binitarianism, torrential, gamer, wise,
# Nearest to four: one, five, pearson, jumper, zero, nine, migrant, mansfeld,
# Nearest to their: the, ketuvim, motions, turnbull, impedes, week, leadership, helpful,
# Nearest to used: might, underlying, euphemistic, solver, augmentation, paradigm, shipped, battery,
# Nearest to taking: heated, portage, inspections, prodigal, courtroom, fateful, essais, interrelated,
# Nearest to articles: pagan, conferred, jackpots, versed, strongly, karoo, patronymics, indexing,
# Nearest to lived: beatified, bayern, lia, hogeschool, portals, personalities, ul, faure,
# Nearest to something: spectrometer, right, willey, golomb, stew, cowdery, magnetic, otherwise,
# Nearest to report: anxious, oran, subcultures, rearrangements, speculatively, glarus, hawat, albans,
# Nearest to running: kakatiya, redeeming, networked, litigated, insignificant, neopagans, picked, supper,
# Nearest to professional: adventurers, pep, longbows, grimm, songwriters, forty, remarkable, underlie,
# Nearest to grand: micronova, thessaloniki, tuareg, margrave, return, poke, still, hospitalised,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4401 0.0779 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4217 0.0770 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4525 0.0774 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4133 0.0776 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4380 0.0772 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4564 0.0767 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3689 0.0773 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3630 0.0768 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4003 0.0766 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3652 0.0775 sec/batch
# Nearest to which: residues, thus, meister, raise, properties, zayd, individual, subtracting,
# Nearest to history: hers, treading, wilson, indebted, tokai, audubon, andes, rumelia,
# Nearest to seven: six, eight, writer, five, politician, four, hugh, strident,
# Nearest to have: genji, formulated, colonisation, to, bazaar, segregation, antithetical, pressburg,
# Nearest to so: occasionally, head, dopamine, sonata, binitarianism, wise, torrential, gamer,
# Nearest to four: one, five, zero, nine, pearson, mansfeld, jumper, von,
# Nearest to their: ketuvim, helpful, leadership, inhaling, impedes, week, moreover, turnbull,
# Nearest to used: might, underlying, solver, clashing, peripherals, neologism, polyester, bundles,
# Nearest to taking: heated, portage, inspections, courtroom, prodigal, fateful, disorders, interrelated,
# Nearest to articles: pagan, versed, jackpots, karoo, conferred, indexing, patronymics, misr,
# Nearest to lived: beatified, lia, bayern, personalities, portals, hogeschool, symbiodinium, faure,
# Nearest to something: otherwise, spectrometer, golomb, right, cowdery, stew, things, willey,
# Nearest to report: anxious, oran, subcultures, rearrangements, glarus, stratigraphic, benelux, speculatively,
# Nearest to running: redeeming, networked, kakatiya, picked, inadequacy, stepped, litigated, insignificant,
# Nearest to professional: adventurers, longbows, pep, songwriters, forty, underlie, remarkable, grimm,
# Nearest to grand: thessaloniki, tuareg, micronova, margrave, poke, return, duke, sideman,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3700 0.0775 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4005 0.0768 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3712 0.0767 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3746 0.0771 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3924 0.0774 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3748 0.0766 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3951 0.0767 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3831 0.0775 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3375 0.0767 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3122 0.0774 sec/batch
# Nearest to which: thus, residues, the, meister, raise, annuities, zayd, interactively,
# Nearest to history: hers, philippians, tokai, indebted, http, andes, treading, winchester,
# Nearest to seven: six, five, eight, four, three, guillermo, strident, one,
# Nearest to have: formulated, genji, colonisation, to, segregation, inhomogeneous, antithetical, pressburg,
# Nearest to so: occasionally, head, binitarianism, sonata, dopamine, wise, bitrates, halevi,
# Nearest to four: one, five, zero, nine, seven, pearson, migrant, mansfeld,
# Nearest to their: ketuvim, helpful, impedes, diabolical, the, moreover, turnbull, inhaling,
# Nearest to used: peripherals, might, clashing, solver, neologism, polyester, underlying, termination,
# Nearest to taking: heated, portage, inspections, fateful, prodigal, courtroom, interrelated, sign,
# Nearest to articles: pagan, versed, indexing, jackpots, karoo, newsletter, conferred, ghazi,
# Nearest to lived: beatified, lia, bayern, hogeschool, portals, dandies, deutschland, symbiodinium,
# Nearest to something: cowdery, spectrometer, golomb, otherwise, things, right, careless, willey,
# Nearest to report: anxious, oran, subcultures, rearrangements, glarus, benelux, outstripped, satellite,
# Nearest to running: networked, redeeming, kakatiya, stepped, supporting, picked, litigated, inadequacy,
# Nearest to professional: adventurers, pep, longbows, jensen, league, remarkable, grimm, creative,
# Nearest to grand: thessaloniki, micronova, tuareg, margrave, duke, return, sideman, still,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3806 0.0785 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2846 0.0777 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3876 0.0776 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3829 0.0778 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3886 0.0770 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2806 0.0770 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2836 0.0771 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3289 0.0770 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2184 0.0784 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2966 0.0772 sec/batch
# Nearest to which: thus, residues, meister, annuities, raise, the, deciphering, interactively,
# Nearest to history: http, tokai, hers, andes, winchester, philippians, treading, indebted,
# Nearest to seven: six, eight, five, four, one, three, writer, nine,
# Nearest to have: genji, formulated, to, colonisation, eritis, inhomogeneous, compulsive, pressburg,
# Nearest to so: occasionally, sonata, dopamine, binitarianism, head, wise, gamer, waxes,
# Nearest to four: one, five, zero, nine, migrant, seven, pearson, runways,
# Nearest to their: ketuvim, impedes, moreover, helpful, week, diabolical, efforts, inhaling,
# Nearest to used: peripherals, solver, polyester, neologism, might, ufos, connector, underlying,
# Nearest to taking: heated, portage, inspections, courtroom, fateful, prodigal, disorders, interrelated,
# Nearest to articles: pagan, versed, indexing, jackpots, karoo, newsletter, conferred, patronymics,
# Nearest to lived: beatified, lia, bayern, hogeschool, dandies, portals, deutschland, symbiodinium,
# Nearest to something: spectrometer, otherwise, cowdery, things, golomb, pause, believable, ajax,
# Nearest to report: anxious, oran, subcultures, rearrangements, glarus, satellite, outstripped, benelux,
# Nearest to running: networked, supporting, redeeming, kakatiya, stepped, picked, litigated, inadequacy,
# Nearest to professional: adventurers, longbows, pep, league, jensen, songwriters, tiffany, forty,
# Nearest to grand: thessaloniki, tuareg, micronova, margrave, duke, return, universiti, still,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3086 0.0779 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3034 0.0768 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3060 0.0348 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2554 0.0770 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2260 0.0768 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2211 0.0773 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2053 0.0774 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2209 0.0768 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2204 0.0761 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1864 0.0770 sec/batch
# Nearest to which: thus, meister, the, interactively, raise, deciphering, annuities, zayd,
# Nearest to history: http, tokai, philippians, winchester, treading, hers, origins, codices,
# Nearest to seven: six, five, eight, four, three, one, nine, leland,
# Nearest to have: colonisation, formulated, genji, to, compulsive, aegean, segregation, antithetical,
# Nearest to so: occasionally, sonata, dopamine, head, binitarianism, bitrates, waxes, blunder,
# Nearest to four: one, five, zero, nine, migrant, seven, runways, pearson,
# Nearest to their: ketuvim, impedes, week, forks, inhaling, diabolical, feldspars, pedestal,
# Nearest to used: peripherals, polyester, solver, neologism, ufos, shipped, realtime, connector,
# Nearest to taking: heated, inspections, portage, courtroom, fateful, prodigal, disorders, interrelated,
# Nearest to articles: pagan, versed, ecumenical, karoo, patronymics, conferred, jackpots, indexing,
# Nearest to lived: beatified, bayern, homo, lia, dandies, portals, oxymoron, deutschland,
# Nearest to something: cowdery, golomb, spectrometer, otherwise, things, carcassonne, believable, ajax,
# Nearest to report: anxious, oran, satellite, subcultures, rearrangements, outstripped, ora, benelux,
# Nearest to running: kakatiya, networked, supporting, redeeming, motherboards, stepped, picked, litigated,
# Nearest to professional: adventurers, pep, longbows, league, standalone, jensen, test, insolvent,
# Nearest to grand: thessaloniki, micronova, tuareg, margrave, duke, universiti, applauded, ambrogio,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2219 0.0783 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2146 0.0773 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2439 0.0772 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1026 0.0772 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1615 0.0769 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1908 0.0776 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1724 0.0761 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1839 0.0764 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2084 0.0766 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1836 0.0775 sec/batch
# Nearest to which: thus, interactively, bronislaw, deciphering, raise, the, meister, annuities,
# Nearest to history: http, tokai, philippians, origins, codices, gaeltacht, andes, pk,
# Nearest to seven: six, five, eight, four, three, one, nine, leland,
# Nearest to have: to, colonisation, compulsive, inhomogeneous, aegean, genji, overpower, segregation,
# Nearest to so: occasionally, dopamine, head, sonata, bitrates, binitarianism, waxes, blunder,
# Nearest to four: one, five, zero, nine, migrant, seven, eight, runways,
# Nearest to their: impedes, ketuvim, helpful, moreover, week, diabolical, inhaling, efforts,
# Nearest to used: peripherals, polyester, connector, neologism, solver, realtime, shipped, battery,
# Nearest to taking: heated, inspections, portage, courtroom, fateful, interrelated, disorders, duplicates,
# Nearest to articles: pagan, versed, karoo, ecumenical, indexing, newsletter, conferred, patronymics,
# Nearest to lived: beatified, homo, lia, bayern, dandies, archaeological, deutschland, portals,
# Nearest to something: things, golomb, otherwise, cowdery, carcassonne, spectrometer, corrupted, deductive,
# Nearest to report: anxious, satellite, oran, subcultures, outstripped, astronautics, ora, benelux,
# Nearest to running: networked, motherboards, kakatiya, supporting, blocking, geelong, stepped, redeeming,
# Nearest to professional: pep, longbows, league, adventurers, standalone, test, insolvent, jensen,
# Nearest to grand: thessaloniki, tuareg, micronova, margrave, duke, universiti, ambrogio, applauded,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1501 0.0781 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2461 0.0772 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1714 0.0775 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1731 0.0768 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1883 0.0776 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1770 0.0769 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2191 0.0770 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1584 0.0771 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1331 0.0771 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1757 0.0766 sec/batch
# Nearest to which: thus, deciphering, bronislaw, residues, zayd, colourless, the, annuities,
# Nearest to history: http, tokai, winchester, origins, philippians, kolar, scheele, gaeltacht,
# Nearest to seven: six, five, eight, four, three, one, nine, availabilitymales,
# Nearest to have: to, compulsive, inhomogeneous, formulated, fairmount, colonisation, overpower, eritis,
# Nearest to so: occasionally, dopamine, head, wise, bitrates, sonata, blunder, scroll,
# Nearest to four: one, five, zero, nine, seven, migrant, three, eight,
# Nearest to their: moreover, ketuvim, impedes, week, helpful, theon, forks, kassite,
# Nearest to used: peripherals, neologism, polyester, disobeyed, clashing, utilitarians, solver, plugged,
# Nearest to taking: heated, inspections, portage, fateful, courtroom, prodigal, bales, coot,
# Nearest to articles: indexing, pagan, newsletter, newsforge, versed, karoo, jackpots, misr,
# Nearest to lived: beatified, homo, lia, archaeological, dandies, savoy, bayern, deutschland,
# Nearest to something: things, otherwise, golomb, corrupted, cowdery, believable, carcassonne, spectrometer,
# Nearest to report: anxious, satellite, oran, astronautics, subcultures, ora, outstripped, rearrangements,
# Nearest to running: networked, kakatiya, motherboards, geelong, stepped, launcher, metres, supporting,
# Nearest to professional: pep, longbows, league, adventurers, standalone, test, insolvent, intends,
# Nearest to grand: thessaloniki, tuareg, micronova, margrave, duke, universiti, compressive, ambrogio,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2056 0.0777 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1623 0.0773 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1986 0.0767 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1872 0.0770 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1374 0.0768 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1614 0.0769 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1753 0.0766 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1137 0.0780 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1747 0.0771 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2102 0.0775 sec/batch
# Nearest to which: thus, the, meister, deciphering, bronislaw, alans, residues, annuities,
# Nearest to history: http, tokai, origins, gaeltacht, philippians, comprehensive, winchester, portal,
# Nearest to seven: six, five, eight, four, one, three, nine, neurologist,
# Nearest to have: to, genji, formulated, dios, aegean, sensual, segregation, compulsive,
# Nearest to so: occasionally, head, bitrates, blunder, wise, sonata, dopamine, scroll,
# Nearest to four: one, five, zero, nine, seven, eight, three, six,
# Nearest to their: ketuvim, moreover, the, impedes, efforts, diabolical, rebelled, week,
# Nearest to used: peripherals, neologism, appended, polyester, disobeyed, solver, misspellings, utilitarians,
# Nearest to taking: heated, portage, inspections, fateful, courtroom, bales, embarrassing, prodigal,
# Nearest to articles: pagan, indexing, newsletter, newsforge, versed, karoo, patronymics, misr,
# Nearest to lived: beatified, homo, archaeological, lia, lion, dandies, bayern, wellesley,
# Nearest to something: believable, things, otherwise, carcassonne, cowdery, golomb, corrupted, dont,
# Nearest to report: anxious, satellite, oran, ora, astronautics, subcultures, outstripped, benelux,
# Nearest to running: kakatiya, geelong, networked, motherboards, stepped, decoys, supporting, aitken,
# Nearest to professional: pep, league, longbows, insolvent, adventurers, test, standalone, toronto,
# Nearest to grand: thessaloniki, margrave, tuareg, micronova, duke, universiti, compressive, margraves,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2391 0.0781 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1393 0.0767 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1496 0.0760 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1579 0.0764 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0234 0.0768 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1435 0.0774 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1446 0.0770 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1424 0.0771 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1593 0.0131 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1153 0.0774 sec/batch
# Nearest to which: deciphering, thus, meister, residues, exception, such, the, colourless,
# Nearest to history: http, tokai, gaeltacht, portal, origins, winchester, crs, philippians,
# Nearest to seven: six, eight, five, four, three, one, nine, zero,
# Nearest to have: to, dios, genji, formulated, inhomogeneous, colonisation, weiser, eritis,
# Nearest to so: occasionally, head, waxes, dopamine, sonata, blunder, bitrates, scroll,
# Nearest to four: one, five, zero, seven, nine, migrant, three, eight,
# Nearest to their: week, efforts, ketuvim, forks, diabolical, kassite, crayon, helpful,
# Nearest to used: peripherals, polyester, flawlessly, solver, realtime, appended, connector, disobeyed,
# Nearest to taking: heated, inspections, portage, courtroom, fateful, embarrassing, bales, buyer,
# Nearest to articles: pagan, newsletter, indexing, newsforge, patronymics, karoo, versed, sabha,
# Nearest to lived: beatified, homo, lia, archaeological, lion, symbiodinium, portals, dandies,
# Nearest to something: otherwise, things, carcassonne, believable, even, ajax, dont, corrupted,
# Nearest to report: anxious, satellite, subcultures, oran, ora, outstripped, astronautics, fansite,
# Nearest to running: networked, motherboards, geelong, kakatiya, blocking, troubleshooting, supporting, decoys,
# Nearest to professional: league, pep, longbows, standalone, intends, insolvent, test, toronto,
# Nearest to grand: margrave, thessaloniki, tuareg, micronova, duke, universiti, compressive, ambrogio,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0869 0.0780 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0541 0.0772 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1352 0.0769 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0461 0.0778 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0762 0.0776 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0407 0.0775 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0963 0.0758 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1029 0.0768 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1329 0.0767 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0210 0.0770 sec/batch
# Nearest to which: deciphering, the, meister, thus, alans, exception, interactively, astatine,
# Nearest to history: http, tokai, origins, crs, gaeltacht, philippians, winchester, kolar,
# Nearest to seven: six, five, eight, three, four, one, nine, availabilitymales,
# Nearest to have: to, colonisation, compulsive, genji, weiser, formulated, inhomogeneous, pillaged,
# Nearest to so: occasionally, head, dopamine, scroll, blunder, waxes, sonata, bitrates,
# Nearest to four: one, five, zero, seven, nine, migrant, three, eight,
# Nearest to their: the, week, efforts, hallucinogenic, rebelled, with, moreover, forks,
# Nearest to used: peripherals, realtime, shipped, polyester, armature, katakana, saxon, solver,
# Nearest to taking: heated, portage, inspections, courtroom, fateful, embarrassing, duplicates, ecotage,
# Nearest to articles: pagan, newsletter, indexing, karoo, patronymics, newsforge, sabha, versed,
# Nearest to lived: homo, beatified, lion, archaeological, dandies, portals, lia, lowlanders,
# Nearest to something: carcassonne, believable, even, otherwise, golomb, cowdery, things, toughening,
# Nearest to report: satellite, anxious, astronautics, ora, subcultures, outstripped, oran, fansite,
# Nearest to running: kakatiya, motherboards, geelong, networked, blocking, troubleshooting, seeded, supporting,
# Nearest to professional: league, pep, standalone, longbows, goals, insolvent, test, intends,
# Nearest to grand: margrave, thessaloniki, duke, micronova, universiti, tuareg, compressive, margraves,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0154 0.0786 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0271 0.0775 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0090 0.0769 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0567 0.0775 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0790 0.0770 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0333 0.0771 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0478 0.0773 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1060 0.0771 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0426 0.0775 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0710 0.0772 sec/batch
# Nearest to which: the, deciphering, thus, interactively, exception, opcodes, residues, such,
# Nearest to history: http, tokai, philippians, crs, origins, comprehensive, winchester, portal,
# Nearest to seven: six, five, eight, four, three, one, nine, zero,
# Nearest to have: to, dios, colonisation, inhomogeneous, zebra, rearing, formulated, we,
# Nearest to so: occasionally, head, scroll, blunder, dopamine, bitrates, waxes, sonata,
# Nearest to four: one, five, zero, nine, seven, three, migrant, eight,
# Nearest to their: week, the, impedes, moreover, efforts, helpful, hallucinogenic, ketuvim,
# Nearest to used: peripherals, solver, disobeyed, neologism, armature, polyester, realtime, misspellings,
# Nearest to taking: heated, inspections, portage, courtroom, fateful, embarrassing, duplicates, buyer,
# Nearest to articles: newsletter, pagan, indexing, newsforge, karoo, sabha, cartographic, versed,
# Nearest to lived: beatified, homo, lion, lia, dandies, wellesley, portals, archaeological,
# Nearest to something: things, otherwise, even, corrupted, believable, cowdery, golomb, carcassonne,
# Nearest to report: satellite, anxious, astronautics, subcultures, outstripped, ora, rectifying, fansite,
# Nearest to running: geelong, kakatiya, motherboards, networked, troubleshooting, blocking, seeded, decoys,
# Nearest to professional: pep, league, standalone, intends, longbows, insolvent, goals, association,
# Nearest to grand: margrave, thessaloniki, micronova, duke, universiti, tuareg, compressive, ambrogio,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0648 0.0784 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1195 0.0773 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0591 0.0769 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0714 0.0766 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0721 0.0775 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0554 0.0775 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0696 0.0778 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0679 0.0772 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0849 0.0774 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0711 0.0764 sec/batch
# Nearest to which: the, deciphering, alans, exception, of, thus, bishoprics, bronislaw,
# Nearest to history: http, origins, gaeltacht, sumeria, largely, philippians, tokai, crs,
# Nearest to seven: six, five, eight, three, one, four, nine, zero,
# Nearest to have: to, dios, colonisation, lenihan, rearing, weiser, formulated, germanic,
# Nearest to so: occasionally, blunder, head, bitrates, scroll, sonata, dopamine, rus,
# Nearest to four: one, five, zero, seven, nine, three, six, eight,
# Nearest to their: the, week, efforts, moreover, would, with, by, impedes,
# Nearest to used: peripherals, disobeyed, neologism, katakana, solver, saxon, misspellings, polyester,
# Nearest to taking: heated, portage, inspections, embarrassing, fateful, aamir, persians, courtroom,
# Nearest to articles: newsletter, indexing, pagan, newsforge, etc, cartographic, sabha, patronymics,
# Nearest to lived: beatified, homo, lion, archaeological, wellesley, lia, symbiodinium, dandies,
# Nearest to something: otherwise, even, things, carcassonne, cowdery, golomb, corrupted, believable,
# Nearest to report: satellite, anxious, astronautics, subcultures, ora, outstripped, fansite, oran,
# Nearest to running: kakatiya, geelong, motherboards, networked, troubleshooting, litigated, blocking, decoys,
# Nearest to professional: pep, league, goals, standalone, longbows, intends, insolvent, test,
# Nearest to grand: margrave, duke, thessaloniki, micronova, universiti, tuareg, margraves, compressive,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0401 0.0785 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0141 0.0766 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0458 0.0769 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0774 0.0776 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0733 0.0777 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1285 0.0768 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1545 0.0773 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0454 0.0763 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0388 0.0766 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0490 0.0762 sec/batch
# Nearest to which: the, deciphering, thus, residues, pendulum, maglev, opcodes, annuities,
# Nearest to history: http, crs, origins, largely, sumeria, winchester, dutton, tokai,
# Nearest to seven: six, five, eight, three, one, four, nine, zero,
# Nearest to have: dios, to, zebra, colonisation, rearing, weiser, inhomogeneous, germanic,
# Nearest to so: head, occasionally, dopamine, sonata, bitrates, blunder, babel, scroll,
# Nearest to four: one, five, zero, nine, seven, three, two, six,
# Nearest to their: the, week, efforts, moreover, hallucinogenic, with, emigr, accordions,
# Nearest to used: peripherals, katakana, misspellings, wtro, realtime, disobeyed, polyester, solver,
# Nearest to taking: heated, portage, inspections, embarrassing, fateful, freitas, duplicates, courtroom,
# Nearest to articles: newsletter, indexing, pagan, etc, newsforge, cartographic, sabha, karoo,
# Nearest to lived: beatified, homo, lia, symbiodinium, dandies, wellesley, lion, archaeological,
# Nearest to something: otherwise, things, believable, cowdery, toughening, even, golomb, dont,
# Nearest to report: satellite, anxious, astronautics, ora, subcultures, oran, outstripped, resolution,
# Nearest to running: kakatiya, geelong, motherboards, networked, litigated, aitken, troubleshooting, feelin,
# Nearest to professional: pep, league, standalone, goals, intends, toronto, practicing, association,
# Nearest to grand: margrave, duke, universiti, thessaloniki, tuareg, micronova, margraves, compressive,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9969 0.0783 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0444 0.0771 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0192 0.0769 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0303 0.0772 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0412 0.0777 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0527 0.0686 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0161 0.0766 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9961 0.0772 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9804 0.0771 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9942 0.0767 sec/batch
# Nearest to which: the, deciphering, thus, exception, such, alans, astatine, disbandment,
# Nearest to history: http, crs, largely, dutton, philippians, codices, sumeria, origins,
# Nearest to seven: six, eight, five, three, one, four, nine, zero,
# Nearest to have: to, dios, rearing, colonisation, zebra, germanic, lenihan, formulated,
# Nearest to so: occasionally, sonata, bitrates, blunder, head, waxes, woodpecker, ils,
# Nearest to four: one, five, zero, three, seven, nine, two, eight,
# Nearest to their: week, efforts, the, by, with, would, hallucinogenic, moreover,
# Nearest to used: peripherals, realtime, katakana, polyester, disobeyed, misspellings, shipped, saxon,
# Nearest to taking: heated, portage, inspections, fateful, courtroom, buyer, embarrassing, duplicates,
# Nearest to articles: newsletter, indexing, pagan, cartographic, etc, newsforge, patronymics, sabha,
# Nearest to lived: homo, beatified, lion, dandies, lia, wellesley, symbiodinium, soulful,
# Nearest to something: things, cowdery, toughening, golomb, otherwise, even, carcassonne, prescient,
# Nearest to report: satellite, astronautics, anxious, ora, subcultures, com, pdf, oran,
# Nearest to running: kakatiya, geelong, motherboards, networked, troubleshooting, blocking, seeded, decoys,
# Nearest to professional: pep, standalone, intends, league, practicing, goals, longbows, toronto,
# Nearest to grand: margrave, duke, universiti, thessaloniki, tuareg, compressive, micronova, margraves,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9812 0.0787 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9653 0.0776 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0085 0.0765 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0262 0.0769 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0089 0.0769 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0062 0.0776 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9238 0.0772 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9766 0.0771 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9352 0.0775 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9733 0.0769 sec/batch
# Nearest to which: the, deciphering, thus, exception, such, autoimmune, opcodes, alans,
# Nearest to history: http, crs, largely, sumeria, origins, tokai, portal, pygmies,
# Nearest to seven: six, eight, five, three, one, four, nine, zero,
# Nearest to have: to, dios, zebra, rearing, lenihan, colonisation, weiser, jared,
# Nearest to so: occasionally, blunder, sonata, head, bitrates, rus, dopamine, waxes,
# Nearest to four: one, five, zero, three, seven, nine, six, two,
# Nearest to their: the, week, by, to, with, efforts, would, accordions,
# Nearest to used: peripherals, use, katakana, realtime, disobeyed, misspellings, polyester, siais,
# Nearest to taking: heated, portage, inspections, fateful, freitas, courtroom, buyer, embarrassing,
# Nearest to articles: newsletter, indexing, pagan, cartographic, etc, sabha, newsforge, misr,
# Nearest to lived: homo, beatified, wellesley, dandies, ecliptic, lion, soulful, symbiodinium,
# Nearest to something: carcassonne, dont, even, things, otherwise, prescient, golomb, believable,
# Nearest to report: satellite, astronautics, ora, anxious, com, fansite, oran, subcultures,
# Nearest to running: kakatiya, geelong, motherboards, seeded, decoys, networked, litigated, troubleshooting,
# Nearest to professional: pep, standalone, association, league, practicing, intends, schools, longbows,
# Nearest to grand: margrave, duke, universiti, thessaloniki, compressive, micronova, tuareg, margraves,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9993 0.0773 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0063 0.0774 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9677 0.0771 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0016 0.0754 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0206 0.0767 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9604 0.0772 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9983 0.0768 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0012 0.0767 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0055 0.0775 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0021 0.0768 sec/batch
# Nearest to which: the, deciphering, riddle, thus, meister, pendulum, such, exception,
# Nearest to history: http, crs, largely, sumeria, dutton, collaborative, tokai, philippians,
# Nearest to seven: six, eight, five, one, three, four, nine, zero,
# Nearest to have: to, dios, weiser, zebra, rearing, lenihan, vga, babylonians,
# Nearest to so: occasionally, blunder, bitrates, dopamine, head, sonata, scroll, woodpecker,
# Nearest to four: one, five, zero, nine, three, seven, six, two,
# Nearest to their: week, the, efforts, by, would, to, desecration, not,
# Nearest to used: peripherals, misspellings, disobeyed, use, realtime, katakana, polyester, siais,
# Nearest to taking: portage, heated, inspections, fateful, freitas, embarrassing, levon, courtroom,
# Nearest to articles: newsletter, indexing, etc, newsforge, cartographic, pagan, newspapers, effector,
# Nearest to lived: homo, beatified, wellesley, symbiodinium, lion, dandies, lia, personalities,
# Nearest to something: things, even, otherwise, dont, prescient, corrupted, golomb, imagined,
# Nearest to report: satellite, astronautics, com, ora, fansite, pdf, anxious, impairments,
# Nearest to running: geelong, kakatiya, motherboards, seeded, decoys, troubleshooting, aitken, networked,
# Nearest to professional: pep, practicing, standalone, intends, schools, association, goals, league,
# Nearest to grand: margrave, duke, universiti, compressive, thessaloniki, micronova, margraves, tuareg,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0002 0.0780 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9691 0.0771 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0176 0.0767 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0069 0.0769 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9831 0.0776 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9896 0.0767 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9924 0.0770 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9624 0.0779 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9679 0.0768 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0301 0.0773 sec/batch
# Nearest to which: the, of, thus, deciphering, such, residues, annuities, exception,
# Nearest to history: http, largely, pygmies, crs, sumeria, anatolia, comprehensive, origins,
# Nearest to seven: six, eight, five, one, three, four, nine, zero,
# Nearest to have: to, dios, zebra, babylonians, germanic, rearing, since, vga,
# Nearest to so: occasionally, blunder, bitrates, rus, sonata, dopamine, woodpecker, head,
# Nearest to four: one, five, zero, three, seven, nine, six, two,
# Nearest to their: the, to, week, efforts, by, would, desecration, not,
# Nearest to used: peripherals, use, misspellings, katakana, adverb, examples, solver, appended,
# Nearest to taking: portage, heated, inspections, freitas, fateful, persians, disorders, buyer,
# Nearest to articles: indexing, newsletter, cartographic, etc, newsforge, pagan, zeitung, valentinians,
# Nearest to lived: homo, beatified, symbiodinium, lia, lion, dandies, wellesley, ecliptic,
# Nearest to something: things, even, otherwise, certainly, golomb, dont, prescient, corrupted,
# Nearest to report: satellite, astronautics, pdf, ora, fansite, com, oran, anxious,
# ...
# Nearest to history: sumeria, contemplative, http, topics, external, hydrothermal, pygmies, comprehensive,
# Nearest to seven: one, six, eight, three, five, four, nine, two,
# Nearest to have: been, are, and, a, to, is, for, there,
# Nearest to so: because, acknowledge, occasionally, blunder, scroll, head, ils, psychoacoustic,
# Nearest to four: one, five, three, zero, eight, seven, nine, six,
# Nearest to their: to, week, they, have, not, the, are, and,
# Nearest to used: use, as, examples, katakana, are, peripherals, inexpensive, misspellings,
# Nearest to taking: portage, puts, disorders, unilateral, buyer, bhindranwale, holds, petrels,
# Nearest to articles: newsletter, cartographic, fagatogo, etc, glory, indexing, article, effector,
# Nearest to lived: generations, homo, ecliptic, wellesley, siblings, barat, lyc, mspf,
# Nearest to something: certainly, things, even, underscore, carcassonne, provably, proposition, otherwise,
# Nearest to report: satellite, impairments, ora, politiken, terror, primer, spacewalks, commission,
# Nearest to running: kakatiya, geelong, primarily, line, seeding, motherboards, quarterbacks, abated,
# Nearest to professional: practicing, pep, junior, wrestler, schools, filmfour, embry, accreditation,
# Nearest to grand: duke, limestone, tabula, compressive, sideman, ghaznavids, regicide, tuareg,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8552 0.0783 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8513 0.0758 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8437 0.0754 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8485 0.0757 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8458 0.0754 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8777 0.0751 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8418 0.0766 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8825 0.0766 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8832 0.0768 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8369 0.0774 sec/batch
# Nearest to which: the, of, and, a, in, an, such, riddle,
# Nearest to history: http, external, sumeria, topics, contemplative, comprehensive, pygmies, hydrothermal,
# Nearest to seven: six, one, five, eight, three, four, nine, two,
# Nearest to have: been, and, are, to, is, a, for, there,
# Nearest to so: because, acknowledge, occasionally, head, blunder, sonata, retold, scroll,
# Nearest to four: one, five, three, zero, eight, nine, seven, six,
# Nearest to their: to, week, have, they, and, not, do, are,
# Nearest to used: use, as, examples, katakana, are, misspellings, cel, groklaw,
# Nearest to taking: portage, puts, disorders, unilateral, holds, petrels, pakistan, bhindranwale,
# Nearest to articles: newsletter, cartographic, fagatogo, article, etc, zeitung, indexing, sheet,
# Nearest to lived: generations, siblings, homo, wellesley, ecliptic, barat, lyc, zygmunt,
# Nearest to something: certainly, things, even, proposition, heard, dupin, carcassonne, underscore,
# Nearest to report: satellite, impairments, politiken, ora, terror, com, commission, spacewalks,
# Nearest to running: kakatiya, geelong, primarily, line, seeding, motherboards, quarterbacks, abated,
# Nearest to professional: practicing, pep, wrestler, standalone, junior, embry, filmfour, echolocation,
# Nearest to grand: duke, limestone, regicide, tabula, record, compressive, sideman, tuareg,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8720 0.0786 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8571 0.0775 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8179 0.0776 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8503 0.0770 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8940 0.0761 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8186 0.0769 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9706 0.0781 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8991 0.0774 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9288 0.0765 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8317 0.0766 sec/batch
# Nearest to which: the, of, a, an, and, such, s, riddle,
# Nearest to history: sumeria, external, http, contemplative, topics, comprehensive, hydrothermal, pygmies,
# Nearest to seven: one, six, five, three, eight, four, nine, two,
# Nearest to have: been, are, and, a, has, there, is, to,
# Nearest to so: because, acknowledge, head, occasionally, retold, gandalf, conform, we,
# Nearest to four: one, five, three, zero, nine, eight, two, seven,
# Nearest to their: to, week, have, they, do, are, not, and,
# Nearest to used: use, as, examples, katakana, are, misspellings, outcroppings, common,
# Nearest to taking: portage, puts, holds, disorders, buyer, summations, petrels, bhindranwale,
# Nearest to articles: newsletter, cartographic, fagatogo, article, indexing, zeitung, etc, newspapers,
# Nearest to lived: generations, siblings, barat, wellesley, drummers, homo, ecliptic, lyc,
# Nearest to something: certainly, things, heard, impassioned, dupin, really, underscore, proposition,
# Nearest to report: satellite, impairments, politiken, ora, commission, terror, investigated, ozone,
# Nearest to running: kakatiya, geelong, primarily, line, seeding, quarterbacks, motherboards, mauricien,
# Nearest to professional: practicing, pep, wrestler, embry, accreditation, junior, filmfour, standalone,
# Nearest to grand: duke, limestone, regicide, tuareg, tabula, gdu, ghaznavids, record,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8069 0.0779 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8555 0.0764 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7836 0.0758 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8727 0.0759 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8396 0.0768 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8608 0.0767 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8987 0.0371 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8193 0.0773 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8495 0.0770 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8199 0.0768 sec/batch
# Nearest to which: the, of, and, a, riddle, an, from, such,
# Nearest to history: external, sumeria, contemplative, http, hydrothermal, topics, portal, comprehensive,
# Nearest to seven: one, six, eight, three, five, four, nine, two,
# Nearest to have: been, are, and, a, to, that, in, for,
# Nearest to so: because, acknowledge, we, gandalf, occasionally, ils, head, waxes,
# Nearest to four: one, five, three, zero, eight, seven, nine, two,
# Nearest to their: to, week, have, do, they, not, are, by,
# Nearest to used: use, as, examples, katakana, are, qm, misspellings, inexpensive,
# Nearest to taking: portage, puts, buyer, holds, bhindranwale, petrels, disorders, unilateral,
# Nearest to articles: fagatogo, newsletter, cartographic, article, editorial, patronymics, zeitung, newspapers,
# Nearest to lived: generations, siblings, homo, isotope, barat, ecliptic, wellesley, boltzmann,
# Nearest to something: certainly, things, underscore, boats, carcassonne, heard, really, dupin,
# Nearest to report: ora, satellite, commission, politiken, impairments, investigated, terror, technical,
# Nearest to running: kakatiya, geelong, primarily, line, quarterbacks, seeding, motherboards, mauricien,
# Nearest to professional: practicing, pep, wrestler, embry, standalone, filmfour, accreditation, junior,
# Nearest to grand: duke, limestone, regicide, compressive, ghaznavids, tabula, gdu, record,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8686 0.0781 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8338 0.0765 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8221 0.0781 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7963 0.0768 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8657 0.0775 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8379 0.0769 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8678 0.0772 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7484 0.0768 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8222 0.0774 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8065 0.0775 sec/batch
# Nearest to which: the, of, a, an, and, in, such, from,
# Nearest to history: topics, external, sumeria, contemplative, http, hydrothermal, portal, famines,
# Nearest to seven: six, one, three, five, eight, four, nine, two,
# Nearest to have: been, are, a, and, to, there, is, for,
# Nearest to so: because, acknowledge, we, gandalf, scroll, head, tisza, occasionally,
# Nearest to four: one, five, three, zero, seven, nine, eight, six,
# Nearest to their: to, they, do, not, are, week, and, have,
# Nearest to used: use, as, are, examples, katakana, mixture, common, also,
# Nearest to taking: portage, puts, buyer, holds, electrochemical, summations, bhindranwale, contravening,
# Nearest to articles: fagatogo, cartographic, newsletter, article, etc, newspapers, glory, effector,
# Nearest to lived: generations, homo, siblings, wellesley, ecliptic, isotope, barat, lyc,
# Nearest to something: certainly, things, underscore, boats, even, really, reclaiming, carcassonne,
# Nearest to report: ora, satellite, commission, politiken, terror, summary, impairments, investigated,
# Nearest to running: kakatiya, geelong, primarily, line, seeding, undirected, quarterbacks, then,
# Nearest to professional: practicing, pep, wrestler, junior, embry, accreditation, association, filmfour,
# Nearest to grand: duke, limestone, regicide, ghaznavids, tabula, tuareg, gdu, compressive,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7416 0.0784 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8048 0.0770 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8647 0.0766 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8366 0.0776 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7991 0.0763 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8942 0.0768 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8297 0.0774 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8137 0.0773 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8535 0.0768 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8257 0.0770 sec/batch
# Nearest to which: the, of, a, and, an, such, in, from,
# Nearest to history: topics, contemplative, sumeria, external, hydrothermal, http, links, museum,
# Nearest to seven: six, one, three, eight, five, four, nine, two,
# Nearest to have: are, been, and, a, to, is, there, many,
# Nearest to so: because, acknowledge, gandalf, head, scroll, we, consequently, mainframes,
# Nearest to four: one, five, three, zero, nine, eight, seven, six,
# Nearest to their: to, they, week, have, and, are, do, not,
# Nearest to used: use, as, are, examples, common, mixture, inexpensive, groklaw,
# Nearest to taking: portage, puts, holds, buyer, electrochemical, summations, bhindranwale, tuck,
# Nearest to articles: fagatogo, cartographic, newsletter, article, sheet, edit, etc, effector,
# Nearest to lived: homo, generations, siblings, wellesley, lyc, barat, life, bibliographic,
# Nearest to something: certainly, things, really, boats, otherwise, provably, florid, even,
# Nearest to report: impairments, ora, satellite, politiken, technical, terror, investigated, commission,
# Nearest to running: kakatiya, geelong, primarily, line, seeding, quarterbacks, mauricien, undirected,
# Nearest to professional: practicing, wrestler, pep, junior, accreditation, association, embry, bps,
# Nearest to grand: duke, limestone, regicide, ghaznavids, tabula, sideman, prix, linguists,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8892 0.0776 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8346 0.0768 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8077 0.0771 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8551 0.0771 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8848 0.0763 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8383 0.0775 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8526 0.0771 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8334 0.0776 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7780 0.0772 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8019 0.0764 sec/batch
# Nearest to which: the, of, a, and, in, as, from, an,
# Nearest to history: topics, external, links, sumeria, timeline, comprehensive, contemplative, http,
# Nearest to seven: one, six, three, five, eight, four, nine, two,
# Nearest to have: are, and, been, a, there, is, for, many,
# Nearest to so: because, acknowledge, consequently, occasionally, in, deferment, tisza, head,
# Nearest to four: one, five, three, seven, zero, eight, six, nine,
# Nearest to their: to, and, they, have, are, do, week, as,
# Nearest to used: use, as, are, examples, common, many, katakana, also,
# Nearest to taking: portage, puts, holds, electrochemical, forgetting, donne, buyer, summations,
# Nearest to articles: cartographic, fagatogo, newsletter, article, edit, sheet, etc, newspapers,
# Nearest to lived: wellesley, homo, generations, isotope, accompli, ecliptic, siblings, boltzmann,
# Nearest to something: certainly, things, boats, really, heard, condiments, florid, even,
# Nearest to report: commission, impairments, summary, terror, satellite, ora, politiken, ozone,
# Nearest to running: kakatiya, geelong, primarily, line, motherboards, seeding, mauricien, had,
# Nearest to professional: practicing, wrestler, pep, junior, filmfour, embry, standalone, echolocation,
# Nearest to grand: limestone, regicide, duke, tabula, sideman, ghaznavids, prix, tuareg,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8635 0.0786 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8130 0.0775 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9011 0.0771 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8928 0.0772 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8900 0.0758 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8396 0.0772 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.8154 0.0775 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8040 0.0765 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7337 0.0768 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8446 0.0777 sec/batch
# Nearest to which: the, of, a, and, in, such, is, as,
# Nearest to history: external, topics, sumeria, contemplative, timeline, http, portal, links,
# Nearest to seven: one, six, eight, five, three, four, nine, two,
# Nearest to have: are, been, and, a, for, there, is, not,
# Nearest to so: because, acknowledge, occasionally, deferment, pixar, wasn, we, mainframes,
# Nearest to four: one, five, three, zero, eight, two, six, seven,
# Nearest to their: to, they, do, week, as, have, and, them,
# Nearest to used: use, as, examples, are, common, katakana, misspellings, also,
# Nearest to taking: puts, portage, holds, summations, electrochemical, forgetting, buyer, donne,
# Nearest to articles: cartographic, fagatogo, article, edit, newsletter, sheet, etc, indexing,
# Nearest to lived: wellesley, generations, barat, accompli, drummers, lyc, ecliptic, soulful,
# Nearest to something: things, certainly, boats, really, underscore, reclaiming, impassioned, heard,
# Nearest to report: terror, commission, ora, politiken, impairments, investigated, satellite, summary,
# Nearest to running: kakatiya, geelong, primarily, mauricien, motherboards, seeding, caucus, line,
# Nearest to professional: practicing, wrestler, pep, embry, junior, training, accreditation, filmfour,
# Nearest to grand: duke, limestone, regicide, ghaznavids, tuareg, gdu, tabula, prix,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8488 0.0785 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8523 0.0777 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
