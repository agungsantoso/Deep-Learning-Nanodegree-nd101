# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:09, 3.31MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 3580146
# Unique words: 27458

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random
t=1e-5
word_counts= Counter(int_words)
total=len(int_words)
freq = {wi : count / total for wi, count in word_counts.items()}
p_keep = {wi : np.sqrt(t / f) for wi, f in freq.items()}
train_words = [wi for wi in int_words if p_keep[wi] > random.random()] # The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    r = random.randint(1, window_size+1)
    start_idx = idx - r if (idx - r) < 0 else 0
    end_idx = idx + r + 1
    
    return list(set(words[start_idx:idx] + words[idx+1:end_idx]))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(dtype=tf.int32, shape=(None,))
    labels = tf.placeholder(dtype=tf.int32, shape=(None, None))

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform(shape=(n_vocab, n_embedding),
                                              minval=-1, maxval=1))
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(ids=inputs, params=embedding)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal(shape=(n_vocab, n_embedding), 
                                                mean=0, stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.constant(shape=(n_vocab,), dtype=tf.float32, value=0.1))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(labels=labels, inputs=embed,
                                      weights=softmax_w, biases=softmax_b,
                                      num_sampled=n_sampled, num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.1729 0.7933 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.1002 0.7835 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.0151 0.7994 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.1300 0.7752 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.0727 0.7678 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.0170 0.7830 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 4.9833 0.7624 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 4.9326 0.7598 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 4.8552 0.7634 sec/batch
# Epoch 2/10 Iteration: 1000 Avg. Training loss: 4.7971 0.6606 sec/batch
# Nearest to d: emphasis, hundred, ethics, gotten, qe, gdp, refrigeration, past,
# Nearest to five: luminosity, aid, behaved, linking, tyrannical, fullback, bellamy, periodically,
# Nearest to on: cairns, listening, sufficient, melt, claims, factual, discovery, online,
# Nearest to be: ganges, commando, very, patrick, stroke, cementing, breton, envisioned,
# Nearest to he: coaching, attention, escaped, vaguely, treaty, pasternak, disabled, fierce,
# Nearest to new: approve, far, qualities, potential, firearms, filled, tonal, redeemed,
# Nearest to american: overlord, real, potsdamer, production, fertilizer, tyndall, employs, makes,
# Nearest to most: buff, diodorus, cow, maintain, humanists, alexis, contest, grosso,
# Nearest to programs: keywork, enters, manoeuvre, affecting, cosmology, mandaic, requesting, layout,
# Nearest to remain: liber, sword, burying, slipped, alcoba, displays, burrow, precedes,
# Nearest to served: intervene, ambition, decorations, up, luoyang, hong, borrowings, assembl,
# Nearest to active: fleas, coptic, wiley, berry, recovery, macrophages, doors, freeze,
# Nearest to district: riemann, mbox, reference, teen, telnet, eradication, processes, pulse,
# Nearest to centuries: biggest, larry, emitted, failed, extant, annotated, hitler, eof,
# Nearest to revolution: idea, accumulated, zakim, jacksonville, cortical, tested, rub, pronunciations,
# Nearest to square: faire, mo, epa, bearshare, defects, install, garry, analyst,
# Epoch 2/10 Iteration: 1100 Avg. Training loss: 4.7616 0.7847 sec/batch
# Epoch 2/10 Iteration: 1200 Avg. Training loss: 4.6952 0.7870 sec/batch
# Epoch 2/10 Iteration: 1300 Avg. Training loss: 4.7561 0.7748 sec/batch
# Epoch 2/10 Iteration: 1400 Avg. Training loss: 4.6838 0.7586 sec/batch
# Epoch 2/10 Iteration: 1500 Avg. Training loss: 4.7145 0.7739 sec/batch
# Epoch 2/10 Iteration: 1600 Avg. Training loss: 4.7033 0.7638 sec/batch
# Epoch 2/10 Iteration: 1700 Avg. Training loss: 4.6839 0.7605 sec/batch
# Epoch 2/10 Iteration: 1800 Avg. Training loss: 4.6456 0.7501 sec/batch
# Epoch 3/10 Iteration: 1900 Avg. Training loss: 4.6753 0.5472 sec/batch
# Epoch 3/10 Iteration: 2000 Avg. Training loss: 4.6017 0.7807 sec/batch
# Nearest to d: chittagong, fright, emphasis, ethics, qe, gotten, hundred, rosie,
# Nearest to five: luminosity, aid, behaved, linking, tyrannical, bellamy, greetings, budding,
# Nearest to on: cairns, factual, melt, listening, wei, bodybuilder, jpg, bremerhaven,
# Nearest to be: commando, ganges, sanger, cementing, volleys, very, patrick, aorist,
# Nearest to he: coaching, escaped, xv, attention, oboe, roma, censorship, gaussian,
# Nearest to new: firearms, far, qualities, approve, redeemed, tonal, rationalist, shipment,
# Nearest to american: overlord, real, potsdamer, gaia, deserts, fertilizer, manson, vinton,
# Nearest to most: buff, diodorus, alexis, pediatric, maintain, cow, distances, grosso,
# Nearest to programs: keywork, enters, manoeuvre, cosmology, affecting, mandaic, merging, butter,
# Nearest to remain: burying, sword, liber, slipped, alcoba, burrow, displays, unwieldy,
# Nearest to served: intervene, luoyang, ambition, decorations, apparel, assembl, up, fifth,
# Nearest to active: fleas, coptic, wiley, berry, recovery, freeze, macrophages, matte,
# Nearest to district: riemann, telnet, pulse, eradication, mbox, teen, gateway, reference,
# Nearest to centuries: biggest, larry, annotated, hitler, dublin, wingspan, failed, quadrant,
# Nearest to revolution: accumulated, idea, jacksonville, zakim, cortical, rub, tested, pronunciations,
# Nearest to square: mo, faire, epa, defects, bearshare, install, garry, wtoo,
# Epoch 3/10 Iteration: 2100 Avg. Training loss: 4.6057 0.7867 sec/batch
# Epoch 3/10 Iteration: 2200 Avg. Training loss: 4.6204 0.7830 sec/batch
# Epoch 3/10 Iteration: 2300 Avg. Training loss: 4.5863 0.7629 sec/batch
# Epoch 3/10 Iteration: 2400 Avg. Training loss: 4.6051 0.7726 sec/batch
# Epoch 3/10 Iteration: 2500 Avg. Training loss: 4.6258 0.7642 sec/batch
# Epoch 3/10 Iteration: 2600 Avg. Training loss: 4.5458 0.7570 sec/batch
# Epoch 3/10 Iteration: 2700 Avg. Training loss: 4.5900 0.7482 sec/batch
# Epoch 4/10 Iteration: 2800 Avg. Training loss: 4.5949 0.4267 sec/batch
# Epoch 4/10 Iteration: 2900 Avg. Training loss: 4.5706 0.7823 sec/batch
# Epoch 4/10 Iteration: 3000 Avg. Training loss: 4.5427 0.7805 sec/batch
# Nearest to d: chittagong, qe, fright, ethics, emphasis, gotten, hundred, gdp,
# Nearest to five: luminosity, aid, linking, behaved, tyrannical, homestead, greetings, bellamy,
# Nearest to on: cairns, wei, melt, factual, bremerhaven, seaplane, listening, claims,
# Nearest to be: commando, sanger, ganges, volleys, cementing, aorist, very, harold,
# Nearest to he: escaped, coaching, roma, attention, xv, gaussian, oboe, centaur,
# Nearest to new: far, redeemed, approve, firearms, qualities, shipment, rationalist, tonal,
# Nearest to american: overlord, real, gaia, fertilizer, deserts, vinton, employs, manson,
# Nearest to most: buff, diodorus, pediatric, alexis, cow, grosso, maintain, ida,
# Nearest to programs: keywork, enters, manoeuvre, cosmology, affecting, mandaic, dispose, butter,
# Nearest to remain: sword, burying, slipped, burrow, liber, alcoba, displays, rabindranath,
# Nearest to served: intervene, luoyang, ambition, decorations, assembl, apparel, arbroath, antipopes,
# Nearest to active: fleas, wiley, matte, coptic, freeze, recovery, berry, macrophages,
# Nearest to district: riemann, pulse, eradication, telnet, mbox, gateway, teen, reference,
# Nearest to centuries: biggest, larry, wingspan, failed, mande, annotated, dublin, hitler,
# Nearest to revolution: jacksonville, idea, accumulated, rub, cortical, tested, pronunciations, zakim,
# Nearest to square: mo, faire, defects, install, bearshare, epa, wtoo, garry,
# Epoch 4/10 Iteration: 3100 Avg. Training loss: 4.5224 0.7745 sec/batch
# Epoch 4/10 Iteration: 3200 Avg. Training loss: 4.5654 0.7639 sec/batch
# Epoch 4/10 Iteration: 3300 Avg. Training loss: 4.5491 0.7595 sec/batch
# Epoch 4/10 Iteration: 3400 Avg. Training loss: 4.5467 0.7668 sec/batch
# Epoch 4/10 Iteration: 3500 Avg. Training loss: 4.5574 0.7519 sec/batch
# Epoch 4/10 Iteration: 3600 Avg. Training loss: 4.5282 0.7442 sec/batch
# Epoch 5/10 Iteration: 3700 Avg. Training loss: 4.5355 0.3099 sec/batch
# Epoch 5/10 Iteration: 3800 Avg. Training loss: 4.5041 0.7702 sec/batch
# Epoch 5/10 Iteration: 3900 Avg. Training loss: 4.5065 0.7761 sec/batch
# Epoch 5/10 Iteration: 4000 Avg. Training loss: 4.4898 0.7844 sec/batch
# Nearest to d: chittagong, qe, ethics, gotten, fright, riga, oz, hundred,
# Nearest to five: luminosity, aid, tyrannical, linking, behaved, homestead, bellamy, fullback,
# Nearest to on: cairns, bremerhaven, wei, claims, melt, sufficient, listening, factual,
# Nearest to be: commando, sanger, volleys, ganges, cementing, aorist, very, harold,
# Nearest to he: escaped, roma, coaching, gaussian, fierce, oboe, fable, attention,
# Nearest to new: far, approve, shipment, qualities, redeemed, firearms, loyalist, rationalist,
# Nearest to american: real, vinton, overlord, athlete, deserts, gaia, fertilizer, manson,
# Nearest to most: buff, pediatric, diodorus, alexis, maintain, ida, grosso, distances,
# Nearest to programs: keywork, manoeuvre, enters, cosmology, affecting, dispose, mandaic, butter,
# Nearest to remain: sword, slipped, burying, burrow, liber, courier, alcoba, displays,
# Nearest to served: luoyang, antipopes, ambition, intervene, arbroath, decorations, apparel, assembl,
# Nearest to active: fleas, berry, wiley, holley, matte, macrophages, recovery, freeze,
# Nearest to district: riemann, pulse, eradication, telnet, gateway, teen, mbox, amraam,
# Nearest to centuries: biggest, larry, wingspan, failed, annotated, mande, dublin, serious,
# Nearest to revolution: idea, jacksonville, accumulated, cortical, tested, rub, pronunciations, essendon,
# Nearest to square: faire, mo, install, bearshare, antoni, defects, epa, garry,
# Epoch 5/10 Iteration: 4100 Avg. Training loss: 4.5062 0.7644 sec/batch
# Epoch 5/10 Iteration: 4200 Avg. Training loss: 4.4708 0.7569 sec/batch
# Epoch 5/10 Iteration: 4300 Avg. Training loss: 4.4992 0.7736 sec/batch
# Epoch 5/10 Iteration: 4400 Avg. Training loss: 4.4982 0.7499 sec/batch
# Epoch 5/10 Iteration: 4500 Avg. Training loss: 4.4723 0.7527 sec/batch
# Epoch 6/10 Iteration: 4600 Avg. Training loss: 4.5048 0.1958 sec/batch
# Epoch 6/10 Iteration: 4700 Avg. Training loss: 4.4595 0.7715 sec/batch
# Epoch 6/10 Iteration: 4800 Avg. Training loss: 4.4652 0.7811 sec/batch
# Epoch 6/10 Iteration: 4900 Avg. Training loss: 4.4473 0.7879 sec/batch
# Epoch 6/10 Iteration: 5000 Avg. Training loss: 4.4595 0.7624 sec/batch
# Nearest to d: chittagong, qe, ethics, oz, riga, gotten, hundred, fright,
# Nearest to five: luminosity, aid, bellamy, tyrannical, linking, behaved, homestead, histoire,
# Nearest to on: cairns, bremerhaven, claims, wei, sufficient, melt, dyce, discovery,
# Nearest to be: commando, sanger, volleys, ganges, cementing, aorist, measurement, aaliyah,
# Nearest to he: escaped, roma, coaching, fable, gaussian, oboe, fierce, jealous,
# Nearest to new: far, approve, shipment, interbase, qualities, redeemed, loyalist, firearms,
# Nearest to american: athlete, vinton, real, actress, manson, fertilizer, gaia, overlord,
# Nearest to most: buff, pediatric, diodorus, ida, maintain, grosso, alexis, humanists,
# Nearest to programs: keywork, manoeuvre, enters, cosmology, affecting, dispose, austrofascism, butter,
# Nearest to remain: slipped, burrow, burying, sword, courier, liber, reflex, defending,
# Nearest to served: ambition, decorations, apparel, luoyang, intervene, renal, usage, up,
# Nearest to active: fleas, macrophages, wiley, recovery, holley, freeze, matte, berry,
# Nearest to district: pulse, riemann, eradication, gateway, refrigerated, amraam, prima, telnet,
# Nearest to centuries: biggest, larry, annotated, mande, failed, wingspan, dublin, extant,
# Nearest to revolution: idea, jacksonville, cortical, tested, accumulated, rub, pronunciations, zakim,
# Nearest to square: mo, faire, antoni, install, bearshare, defects, wtoo, epa,
# Epoch 6/10 Iteration: 5100 Avg. Training loss: 4.4677 0.7581 sec/batch
# Epoch 6/10 Iteration: 5200 Avg. Training loss: 4.4376 0.7760 sec/batch
# Epoch 6/10 Iteration: 5300 Avg. Training loss: 4.4650 0.7469 sec/batch
# Epoch 6/10 Iteration: 5400 Avg. Training loss: 4.4503 0.7506 sec/batch
# Epoch 7/10 Iteration: 5500 Avg. Training loss: 4.4303 0.0779 sec/batch
# Epoch 7/10 Iteration: 5600 Avg. Training loss: 4.4241 0.7696 sec/batch
# Epoch 7/10 Iteration: 5700 Avg. Training loss: 4.4016 0.7752 sec/batch
# Epoch 7/10 Iteration: 5800 Avg. Training loss: 4.4092 0.7878 sec/batch
# Epoch 7/10 Iteration: 5900 Avg. Training loss: 4.4195 0.7673 sec/batch
# Epoch 7/10 Iteration: 6000 Avg. Training loss: 4.4187 0.7665 sec/batch
# Nearest to d: chittagong, qe, riga, ethics, oz, alphonsus, jules, gotten,
# Nearest to five: luminosity, aid, bellamy, linking, tyrannical, behaved, homestead, protective,
# Nearest to on: cairns, bremerhaven, sufficient, wei, claims, melt, discovery, dyce,
# Nearest to be: commando, sanger, cementing, volleys, measurement, ganges, aorist, harold,
# Nearest to he: escaped, roma, urraca, fierce, coaching, fable, jealous, imran,
# Nearest to new: approve, far, interbase, shipment, loyalist, naacp, honolulu, redeemed,
# Nearest to american: athlete, vinton, actress, real, manson, fertilizer, six, sacrificing,
# Nearest to most: buff, pediatric, diodorus, maintain, ida, grosso, distances, courtesan,
# Nearest to programs: keywork, manoeuvre, enters, affecting, cosmology, layout, butter, dispose,
# Nearest to remain: slipped, burying, burrow, courier, sword, reflex, defending, liber,
# Nearest to served: ambition, apparel, decorations, luoyang, arbroath, antipopes, usage, intervene,
# Nearest to active: fleas, macrophages, holley, wiley, recovery, macroeconomic, matte, adour,
# Nearest to district: pulse, eradication, riemann, refrigerated, amraam, summers, mauritius, gateway,
# Nearest to centuries: biggest, annotated, larry, mande, wingspan, failed, extant, serious,
# Nearest to revolution: jacksonville, idea, cortical, accumulated, tested, pronunciations, rub, essendon,
# Nearest to square: antoni, mo, faire, install, bearshare, garry, wtoo, gustaf,
# Epoch 7/10 Iteration: 6100 Avg. Training loss: 4.4208 0.7790 sec/batch
# Epoch 7/10 Iteration: 6200 Avg. Training loss: 4.4100 0.7546 sec/batch
# Epoch 7/10 Iteration: 6300 Avg. Training loss: 4.4025 0.7499 sec/batch
# Epoch 7/10 Iteration: 6400 Avg. Training loss: 4.4118 0.7653 sec/batch
# Epoch 8/10 Iteration: 6500 Avg. Training loss: 4.4030 0.7368 sec/batch
# Epoch 8/10 Iteration: 6600 Avg. Training loss: 4.3934 0.7789 sec/batch
# Epoch 8/10 Iteration: 6700 Avg. Training loss: 4.4022 0.7889 sec/batch
# Epoch 8/10 Iteration: 6800 Avg. Training loss: 4.4263 0.7657 sec/batch
# Epoch 8/10 Iteration: 6900 Avg. Training loss: 4.3964 0.7541 sec/batch
# Epoch 8/10 Iteration: 7000 Avg. Training loss: 4.3891 0.7725 sec/batch
# Nearest to d: chittagong, qe, jules, riga, ethics, alphonsus, soprano, oz,
# Nearest to five: luminosity, aid, behaved, bellamy, protective, linking, family, parks,
# Nearest to on: cairns, sufficient, bremerhaven, discovery, broad, cour, claims, melt,
# Nearest to be: commando, sanger, measurement, aorist, cementing, volleys, ganges, aaliyah,
# Nearest to he: escaped, roma, fable, urraca, coaching, fierce, jealous, attention,
# Nearest to new: far, approve, interbase, shipment, honolulu, naacp, hunger, extrapolation,
# Nearest to american: athlete, vinton, actress, manson, six, real, fertilizer, sacrificing,
# Nearest to most: buff, pediatric, diodorus, ida, grosso, distances, maintain, falsely,
# Nearest to programs: keywork, manoeuvre, affecting, enters, usb, cosmology, layout, butter,
# Nearest to remain: slipped, courier, burying, burrow, reflex, defending, liber, oder,
# Nearest to served: ambition, decorations, apparel, sundays, arbroath, luoyang, usage, antipopes,
# Nearest to active: fleas, macrophages, holley, wiley, macroeconomic, recovery, matte, adorned,
# Nearest to district: pulse, eradication, riemann, summers, refrigerated, teen, brig, enforcing,
# Nearest to centuries: biggest, larry, annotated, wingspan, mande, failed, extant, serious,
# Nearest to revolution: jacksonville, idea, accumulated, cortical, tested, essendon, zakim, formally,
# Nearest to square: antoni, mo, install, faire, analyst, bearshare, fuchs, wtoo,
# Epoch 8/10 Iteration: 7100 Avg. Training loss: 4.3735 0.7537 sec/batch
# Epoch 8/10 Iteration: 7200 Avg. Training loss: 4.3748 0.7479 sec/batch
# Epoch 8/10 Iteration: 7300 Avg. Training loss: 4.3630 0.7548 sec/batch
# Epoch 9/10 Iteration: 7400 Avg. Training loss: 4.3653 0.6179 sec/batch
# Epoch 9/10 Iteration: 7500 Avg. Training loss: 4.3539 0.7759 sec/batch
# Epoch 9/10 Iteration: 7600 Avg. Training loss: 4.3401 0.7800 sec/batch
# Epoch 9/10 Iteration: 7700 Avg. Training loss: 4.3818 0.7707 sec/batch
# Epoch 9/10 Iteration: 7800 Avg. Training loss: 4.3339 0.7545 sec/batch
# Epoch 9/10 Iteration: 7900 Avg. Training loss: 4.3658 0.7754 sec/batch
# Epoch 9/10 Iteration: 8000 Avg. Training loss: 4.3503 0.7605 sec/batch
# Nearest to d: chittagong, abu, alphonsus, qe, riga, soprano, jules, cartoonist,
# Nearest to five: luminosity, aid, behaved, family, protective, linking, bellamy, davis,
# Nearest to on: cairns, broad, listening, bremerhaven, appears, sufficient, jpg, discovery,
# Nearest to be: commando, measurement, sanger, cementing, aorist, ganges, volleys, awake,
# Nearest to he: escaped, fierce, urraca, fable, jealous, roma, attention, coaching,
# Nearest to new: far, interbase, coincided, approve, naacp, honolulu, hunger, shipment,
# Nearest to american: athlete, vinton, actress, manson, sacrificing, real, fertilizer, six,
# Nearest to most: buff, pediatric, diodorus, ida, grosso, distances, falsely, maintain,
# Nearest to programs: keywork, affecting, manoeuvre, usb, dispose, layout, cosmology, enters,
# Nearest to remain: slipped, courier, burying, burrow, defending, reflex, liber, spiritual,
# Nearest to served: ambition, decorations, apparel, sundays, arbroath, antipopes, industries, usage,
# Nearest to active: macrophages, fleas, holley, macroeconomic, wiley, adequate, adorned, coding,
# Nearest to district: pulse, eradication, summers, riemann, refrigerated, brig, mauritius, enforcing,
# Nearest to centuries: biggest, larry, annotated, wingspan, mande, failed, extant, misery,
# Nearest to revolution: jacksonville, idea, accumulated, cortical, essendon, tested, formally, zakim,
# Nearest to square: antoni, mo, faire, fuchs, install, gustaf, analyst, wtoo,
# Epoch 9/10 Iteration: 8100 Avg. Training loss: 4.3581 0.7610 sec/batch
# Epoch 9/10 Iteration: 8200 Avg. Training loss: 4.3310 0.7520 sec/batch
# Epoch 10/10 Iteration: 8300 Avg. Training loss: 4.4034 0.5070 sec/batch
# Epoch 10/10 Iteration: 8400 Avg. Training loss: 4.3568 0.7811 sec/batch
# Epoch 10/10 Iteration: 8500 Avg. Training loss: 4.3410 0.7838 sec/batch
# Epoch 10/10 Iteration: 8600 Avg. Training loss: 4.3432 0.7817 sec/batch
# Epoch 10/10 Iteration: 8700 Avg. Training loss: 4.3628 0.7679 sec/batch
# Epoch 10/10 Iteration: 8800 Avg. Training loss: 4.3646 0.7725 sec/batch
# Epoch 10/10 Iteration: 8900 Avg. Training loss: 4.3218 0.7665 sec/batch
# Epoch 10/10 Iteration: 9000 Avg. Training loss: 4.3617 0.7581 sec/batch
# Nearest to d: chittagong, alphonsus, abu, riga, inge, cartoonist, jules, activist,
# Nearest to five: luminosity, linking, aid, behaved, mail, davis, bellamy, family,
# Nearest to on: cairns, nursia, listening, appears, broad, melt, sufficient, spree,
# Nearest to be: commando, measurement, cementing, sanger, awake, aorist, freewheelin, ganges,
# Nearest to he: escaped, fierce, urraca, attention, soviets, faithfully, centaur, ageing,
# Nearest to new: far, interbase, naacp, coincided, rationalist, mainline, hunger, honolulu,
# Nearest to american: athlete, vinton, actress, manson, sacrificing, six, real, fertilizer,
# Nearest to most: buff, pediatric, diodorus, ida, distances, falsely, flushing, maintain,
# Nearest to programs: keywork, affecting, manoeuvre, dispose, usb, layout, mandaic, butter,
# Nearest to remain: courier, slipped, burrow, burying, reflex, defending, spiritual, meters,
# Nearest to served: decorations, ambition, apparel, sundays, antipopes, arbroath, usage, unavailable,
# Nearest to active: macrophages, fleas, holley, wiley, macroeconomic, adequate, reichstag, cobalt,
# Nearest to district: pulse, summers, eradication, riemann, brig, refrigerated, enforcing, northeastern,
# Nearest to centuries: biggest, larry, annotated, wingspan, mande, eof, misery, extant,
# Nearest to revolution: idea, jacksonville, cortical, accumulated, essendon, tested, formally, voyages,
# Nearest to square: antoni, mo, fuchs, install, faire, analyst, bearshare, wtoo,
# Epoch 10/10 Iteration: 9100 Avg. Training loss: 4.3484 0.7513 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
